# %%
import requests

x=requests.get('https://www.google.com/search?q=weather+bank')
print(x.text)
# Out:
# <!DOCTYPE html><html lang="bn"><head><title>Google Search</title><style>body{background-color:#fff}</style></head><body><noscript><style>table,div,span,p{display:none}</style><meta content="0;url=/httpservice/retry/enablejs?sei=B3CqZ6XuN6iMnesPr_KNCA" http-equiv="refresh"><div style="display:block">&#2479;&#2470;&#2495; &#2453;&#2527;&#2503;&#2453; &#2488;&#2503;&#2453;&#2503;&#2472;&#2509;&#2465;&#2503;&#2480; &#2478;&#2471;&#2509;&#2479;&#2503; &#2438;&#2474;&#2472;&#2495; &#2437;&#2472;&#2509;&#2479; &#2488;&#2494;&#2439;&#2463;&#2503; &#2472;&#2494; &#2479;&#2494;&#2472; &#2468;&#2494;&#2489;&#2482;&#2503; <a href="/httpservice/retry/enablejs?sei=B3CqZ6XuN6iMnesPr_KNCA">&#2447;&#2454;&#2494;&#2472;&#2503;</a> &#2453;&#2509;&#2482;&#2495;&#2453; &#2453;&#2480;&#2497;&#2472;</div></noscript><script nonce="Y5SaN_W4Vvcqeq5N0c-lsw">//# sourceMappingURL=data:application/json;charset=utf-8;base64,eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cmNlc0NvbnRlbnQiOlsiICJdLCJuYW1lcyI6WyJjbG9zdXJ
# ...

# %%
# Out:
# {"action":"error","status":400,"type":"ERR_BAD_REQUEST"}
